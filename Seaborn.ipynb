# %%
import seaborn as sns
import pandas as pd
data={"Days":[1,2,3,4,5],
     "NOP":[50,40,60,30,44]}
df=pd.DataFrame(data)
print(df)
sns.lineplot(data=data,x="Days",y="NOP")
# Out:
#    Days  NOP
# 0     1   50
# 1     2   40
# 2     3   60
# 3     4   30
# 4     5   44
# <Axes: xlabel='Days', ylabel='NOP'>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
color=sns.color_palette("spring")
sns.lineplot(data=data, x="Education", y="Age", hue="Gender", style="City",palette=color)
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ############## BAR PLOT ###########################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.barplot(data=data , x="JoiningYear",y="PaymentTier")
plt.plot()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.barplot(data=data , x="JoiningYear",y="PaymentTier",estimator="sum")
plt.plot()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.barplot(data=data , x="JoiningYear",y="PaymentTier",hue="Gender",palette="spring")
plt.plot()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
sns.barplot(data=data , x="JoiningYear",y="PaymentTier",hue="Gender",palette="spring",order=[2017, 2018,2012,2015,2016,2013,2014,2012])
plt.plot()
# Out:
# []

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
sns.barplot(data=data , x="JoiningYear",y="PaymentTier",hue="Gender",palette="spring",order=[2017, 2018,2012,2015,2016,2013,2014,2012],errorbar=("ci",0))
plt.plot()
# Out:
# []

# %% [markdown]
# ##########  Hist Plot #####################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
sns.histplot(data=data , x="Age",hue="Gender",kde=True,discrete=True,bins=30)
plt.show()

# %%
###############  SCATTER PLOT #######################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.scatterplot(data=data,x="Age",y="PaymentTier",hue="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ############ HeatMAp Plot ###################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
gp=data.groupby("City").agg({"Age":"mean"})
sns.heatmap(gp)
plt.plot()
# Out:
# []

# %% [markdown]
# ########## count plot ##########################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.countplot(data=data , x="Gender",hue="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.countplot(data=data , x="JoiningYear",hue="Gender",palette="GnBu")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ########### VIOLIN PLOT #######################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.violinplot(data=data , x="Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [raw]
# ###### PAIR PLOT #####################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.pairplot(data)
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.pairplot(data,hue="JoiningYear")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.pairplot(data,hue="JoiningYear",diag_kind="hist")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ########### STRIP PLOT #################

# %%
#Scatter we take x,y in numberic only
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.stripplot(data,x="City",y="JoiningYear",hue="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
#Scatter we take x,y in numberic only
#strip for numberic and string also
# strip it show extact point then bar graph
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.stripplot(data,x="City",y="JoiningYear",dodge=True,jitter=0.5,hue="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ########## BOX PLOT #############

# %%
# if we want to find outiler in data
# we use box plot for representation of statistical data 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.boxplot(data=data,x="Age",y="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
#here numberic value must be y
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.boxplot(data=data,x="Gender",y="Age",orient="vetical")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.boxplot(data=data,x="Gender",y="Age",orient="vetical")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ###############  CAT PLOT #############################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
#cat plot stands for categorical plot 
sns.catplot(data=data,x="Gender",y="Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
#cat plot stands for categorical plot 
sns.catplot(data=data,x="Gender",y="Age",kind="violin")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
#cat plot stands for categorical plot 
sns.catplot(data=data,x="JoiningYear",hue="Gender",kind="count")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ###################  STYLE AND COLOR IN PLOT #########################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)

#sns.set_style(style="dark")
sns.set_style(style="darkgrid")
#sns.set_style(style="whitegrid")

sns.barplot(data=data,x="JoiningYear",y="Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)

sns.set_style(style="ticks")

sns.barplot(data=data,x="JoiningYear",y="Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.palplot(sns.color_palette())
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.palplot(sns.color_palette("viridis"))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.palplot(sns.color_palette("viridis",3))
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.palplot(sns.color_palette("spring"))
plt.show()

# %% [markdown]
# ############## MULTIPLE PLOTS ########################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
a=sns.FacetGrid(data,col="City")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
a=sns.FacetGrid(data,col="City",height=2)
a.map(sns.barplot,"JoiningYear","Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ############ RELATIONAL PLOT ###########################

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.relplot(data=data , x="JoiningYear",y="Age",hue="Gender")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.relplot(data=data , x="JoiningYear",y="Age",hue="Gender",kind="line")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.relplot(data=data , x="JoiningYear",y="Age",hue="Gender",col="City")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %% [markdown]
# ################# SWARM PLOT ###############################

# %%
#no proper data here 
#swamplot to not overlap point so we use swamplot stilldata will remains accurates
"""import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.swarmplot(data=data,x="Age",y="JoiningYear",hue="Gender")
plt.show()"""
# Out:
# 'import seaborn as sns\nimport pandas as pd\nimport matplotlib.pyplot as plt\ndata=pd.read_csv("Employee.csv")\nprint(data)\nsns.swarmplot(data=data,x="Age",y="JoiningYear",hue="Gender")\nplt.show()'

# %% [markdown]
# ################ KDE PLOT ######################

# %%
#KDE stands for Kernal Density Estimation -
# it show frequency of data and flow of data
#it was same as histogram but in histogram bar graph is shows here only wave like structure is there 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
print(data)
sns.kdeplot(data=data ,x="Age")
plt.show()
# Out:
#       Education  JoiningYear       City  PaymentTier  Age  Gender EverBenched  \
# 0     Bachelors         2017  Bangalore            3   34    Male          No
# 1     Bachelors         2013       Pune            1   28  Female          No
# 2     Bachelors         2014  New Delhi            3   38  Female          No
# 3       Masters         2016  Bangalore            3   27    Male          No
# 4       Masters         2017       Pune            3   24    Male         Yes
# ...         ...          ...        ...          ...  ...     ...         ...
# 4648  Bachelors         2013  Bangalore            3   26  Female          No
# 4649    Masters         2013       Pune            2   37    Male          No
# 4650    Masters         2018  New Delhi            3   27    Male          No
# 4651  Bachelors         2012  Bangalore            3   30    Male         Yes
# 4652  Bachelors         2015  Bangalore            3   33    Male         Yes
#
# ...

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
#print(data)
sns.kdeplot(data=data ,x="Age",hue="JoiningYear")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
#print(data)
sns.kdeplot(data=data ,x="Age",hue="JoiningYear",multiple="stack")
plt.show()

# %%
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt
data=pd.read_csv("Employee.csv")
#print(data)
sns.kdeplot(data=data ,x="Age",hue="JoiningYear",multiple="fill")
plt.show()
